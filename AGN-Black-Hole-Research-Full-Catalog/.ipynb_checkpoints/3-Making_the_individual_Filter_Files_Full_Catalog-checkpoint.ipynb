# %% [markdown]
# # <font color='#cec748'>This notebook is to get the individual filters for all the galaxies</font>
# The notebook uses data from the get_spec_example file to:
# - w

# %% [markdown]
# ## <font color='#e55730' size=3 >Imports</font>

# %%
from dustmaps.config import config
config.reset()

# %%
from hetdex_api.detections import Detections
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.coordinates import match_coordinates_sky
from astropy.convolution import convolve, Gaussian1DKernel, Box1DKernel
import tables
import numpy as np
import os.path as op
import math
import os
import h5py

from elixer import global_config as G
G.GLOBAL_LOGGING = True
from elixer import spectrum_utilities as ESU
from elixer import catalogs


from hetdex_api.elixer_widget_cls import ElixerWidget
from hetdex_api.config import HDRconfig
from hetdex_tools.get_spec import get_spectra
from hetdex_api.shot import *
from hetdex_api.survey import FiberIndex
from hetdex_api.detections import Detections

from multiprocessing import Pool
from astropy.table import QTable, Table, Column
from scipy.ndimage import gaussian_filter1d
from scipy.interpolate import interp1d
from scipy import interpolate

import inspect
import scipy.stats as stats
from astropy.table import Table
from astropy.table import QTable, Table, Column
import warnings
from astropy.modeling import models
from specutils.spectra import Spectrum1D, SpectralRegion
from specutils.fitting import fit_generic_continuum
from specutils.fitting.continuum import fit_continuum
from astropy.stats import biweight_location
from scipy.integrate import quad as quad
from numpy.polynomial.polynomial import polyfit
from numpy.polynomial.polynomial import polyval
from photutils.centroids import centroid_2dg, centroid_sources
from photutils.datasets import make_4gaussians_image
from numpy import inf
from photutils.datasets import make_4gaussians_image
from photutils.centroids import centroid_quadratic
# Out:
# Populating dustmaps config with /home/jovyan/Hobby-Eberly-Telesco/hdr3/calib/dustmaps

# %%
import importlib.util
import sys

# For illustrative purposes.
name = 'lmfit'

if name in sys.modules:
    print(f"{name!r} already in sys.modules")
elif (spec := importlib.util.find_spec(name)) is not None:
    # If you choose to perform the actual import ...
    module = importlib.util.module_from_spec(spec)
    sys.modules[name] = module
    spec.loader.exec_module(module)
    print(f"{name!r} has been imported")
else:
    print(f"Nope Installing Now")
    # !pip install lmfit
    condition = True
# Out:
# Nope Installing Now
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lmfit
#   Downloading lmfit-1.3.4-py3-none-any.whl.metadata (8.8 kB)
# Collecting asteval>=1.0 (from lmfit)
#   Downloading asteval-1.0.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.12/site-packages (from lmfit) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.12/site-packages (from lmfit) (1.14.1)
# Collecting uncertainties>=3.2.2 (from lmfit)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: dill>=0.3.4 in /opt/conda/lib/python3.12/site-packages (from lmfit) (0.3.9)
# Downloading lmfit-1.3.4-py3-none-any.whl (97 kB)
# Downloading asteval-1.0.6-py3-none-any.whl (22 kB)
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
# Installing collected packages: uncertainties, asteval, lmfit
# Successfully installed asteval-1.0.6 lmfit-1.3.4 uncertainties-3.2.3

# %% [markdown]
# ## <font color='#e55730' size=3 >Plotting imports and settings</font>

# %%
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rc
import matplotlib.ticker
import matplotlib.patches as patches

# %matplotlib ipympl
plt.style.use('default')
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams.update({'font.size': 14})
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
plt.rcParams['mathtext.default'] = 'regular'
plt.rcParams['xtick.direction']= 'in'
plt.rcParams['ytick.direction']= 'in'
plt.rcParams['xtick.labelsize']= 14.0
plt.rcParams['ytick.labelsize']= 14.0

# %% [markdown]
# ## <font color='#e55730' size=3 >Values</font>

# %%
c = 299792.5 #km s^-1
H_0 = 70 #km s^-1 MpC^-1
R = 800

V = c/R
print(V)
# Out:
# 374.740625

# %% [markdown]
# ## <font color='#e55730' size=3 >Definitions</font>

# %%
pwd
# Out:
# '/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog'

# %% [markdown]
# ## <font color='#e55730' size=3 >Creating Files</font>

# %%
File_New_Catalog = "hetdex_agn_hdr5.fits" #hdr5 check with dustin
File_Redshift_Confirmed = "Table_Spec_Redshift_Confirmed_New_Old.fits"

# %%
Data_New_Catalog = Table.read(File_New_Catalog, format = 'fits')
Data_Redshift_Confirmed = Table.read(File_Redshift_Confirmed, format = 'fits')

print(len(Data_New_Catalog["detectid_best"]))

for value in Data_New_Catalog["snr_MgII"]:
    if abs(value) <= 0:
        print(value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Data_New_Catalog = Table.read(File_New_Catalog, format = 'fits')
#       2 Data_Redshift_Confirmed = Table.read(File_Redshift_Confirmed, format = 'fits')
#       4 print(len(Data_New_Catalog["detectid_best"]))
#
# File /opt/conda/lib/python3.12/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/registry/core.py:221, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     218         kwargs.update({"filename": path})
#     220 reader = self.get_reader(format, cls)
# --> 221 data = reader(*args, **kwargs)
#     223 if not isinstance(data, cls):
#     224     # User has read with a subclass where only the parent class is
#     225     # registered.  This returns the parent class, so try coercing
#     226     # to desired subclass.
#     227     try:
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/connect.py:252, in read_table_fits(input, hdu, astropy_native, memmap, character_as_bytes, unit_parse_strict, mask_invalid, strip_spaces)
#     249     mask_invalid = False
#     250     strip_spaces = False
# --> 252 hdulist = fits_open(input, character_as_bytes=character_as_bytes, memmap=memmap)
#     254 try:
#     255     return read_table_fits(
#     256         hdulist,
#     257         hdu=hdu,
#    (...)
#     261         strip_spaces=strip_spaces,
#     262     )
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:220, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     217 if not name:
#     218     raise ValueError(f"Empty filename: {name!r}")
# --> 220 return HDUList.fromfile(
#     221     name,
#     222     mode,
#     223     memmap,
#     224     save_backup,
#     225     cache,
#     226     lazy_load_hdus,
#     227     ignore_missing_simple,
#     228     use_fsspec=use_fsspec,
#     229     fsspec_kwargs=fsspec_kwargs,
#     230     decompress_in_memory=decompress_in_memory,
#     231     **kwargs,
#     232 )
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:484, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     465 @classmethod
#     466 def fromfile(
#     467     cls,
#    (...)
#     475     **kwargs,
#     476 ):
#     477     """
#     478     Creates an `HDUList` instance from a file-like object.
#     479
#    (...)
#     482     documentation for details of the parameters accepted by this method).
#     483     """
# --> 484     return cls._readfrom(
#     485         fileobj=fileobj,
#     486         mode=mode,
#     487         memmap=memmap,
#     488         save_backup=save_backup,
#     489         cache=cache,
#     490         ignore_missing_simple=ignore_missing_simple,
#     491         lazy_load_hdus=lazy_load_hdus,
#     492         **kwargs,
#     493     )
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:1186, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1183 if fileobj is not None:
#    1184     if not isinstance(fileobj, _File):
#    1185         # instantiate a FITS file object (ffo)
# -> 1186         fileobj = _File(
#    1187             fileobj,
#    1188             mode=mode,
#    1189             memmap=memmap,
#    1190             cache=cache,
#    1191             use_fsspec=use_fsspec,
#    1192             fsspec_kwargs=fsspec_kwargs,
#    1193             decompress_in_memory=decompress_in_memory,
#    1194         )
#    1195     # The Astropy mode is determined by the _File initializer if the
#    1196     # supplied mode was None
#    1197     mode = fileobj.mode
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/file.py:240, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     238     self._open_fileobj(fileobj, mode, overwrite)
#     239 elif isinstance(fileobj, (str, bytes)):
# --> 240     self._open_filename(fileobj, mode, overwrite)
#     241 else:
#     242     self._open_filelike(fileobj, mode, overwrite)
#
# File /opt/conda/lib/python3.12/site-packages/astropy/io/fits/file.py:701, in _File._open_filename(self, filename, mode, overwrite)
#     698 ext = os.path.splitext(self.name)[1]
#     700 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 701     self._file = open(self.name, IO_FITS_MODES[mode])
#     702     self.close_on_error = True
#     704 # Make certain we're back at the beginning of the file
#     705 # BZ2File does not support seek when the file is open for writing, but
#     706 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hetdex_agn_hdr5.fits'

# %%
catlib = catalogs.CatalogLibrary()
print(len(Data_New_Catalog["detectid_best"]))

# %% [markdown]
# ## <font color='#e55730' size=3 >Getting the Redshift and AGN confirmed</font>

# %%
sel = (np.array(Data_New_Catalog['z'] > 0.25) & np.array(Data_New_Catalog['z'] < 0.96)) #This is the redshift range to capture MgII
sel = sel & np.array(Data_New_Catalog['zflag'] == 1) #We only want zflag = 1 because it means the redshift has been confirmed by line pairs or SDSS
sel = sel & np.array(Data_New_Catalog["agn_flag"] == 1) #We only want agns

#print(len(Data_New_Catalog[sel]))
#combined_data = Data_New_Catalog[sel]

print(len(combined_data["z"]))

The_Redshifts_Combined = []
The_IDs_Combined = []
The_RAs_Combined = []
The_DECs_Combined = []

for a, b, c, d, e, f in zip(Data_New_Catalog['zflag'], 
                             Data_New_Catalog["agn_flag"], 
                             Data_New_Catalog['z'], 
                             Data_New_Catalog['detectid_best'], 
                             Data_New_Catalog['ra'], 
                             Data_New_Catalog['dec']):
    if a == 1 and b == 1:
        if 0.25 <= c <= 0.96:
            The_Redshifts_Combined.append(c)
            The_IDs_Combined.append(d)
            The_RAs_Combined.append(e)
            The_DECs_Combined.append(f)
            

# Combine all arrays
The_Redshifts_Combined = np.concatenate((Data_Redshift_Confirmed["z"], The_Redshifts_Combined))
The_IDs_Combined = np.concatenate((Data_Redshift_Confirmed["Detectid"], The_IDs_Combined))
The_RAs_Combined = np.concatenate((Data_Redshift_Confirmed["RA"], The_RAs_Combined))
The_DECs_Combined = np.concatenate((Data_Redshift_Confirmed["DEC"], The_DECs_Combined))

# Create a dictionary to store unique entries
# Using detectid as the key ensures uniqueness
combined_dict = {}

for i in range(len(The_IDs_Combined)):
    detectid = The_IDs_Combined[i]
    # Only add if this detectid hasn't been seen before
    # This keeps the first occurrence of each detectid
    if detectid not in combined_dict:
        combined_dict[detectid] = {
            'z': The_Redshifts_Combined[i],
            'RA': The_RAs_Combined[i],
            'DEC': The_DECs_Combined[i]
        }

# If you prefer a structure similar to your original data:
combined_data = {
    'Detectid': np.array(list(combined_dict.keys())),
    'z': np.array([combined_dict[did]['z'] for did in combined_dict.keys()]),
    'RA': np.array([combined_dict[did]['RA'] for did in combined_dict.keys()]),
    'DEC': np.array([combined_dict[did]['DEC'] for did in combined_dict.keys()])
}

print(f"Original length: {len(The_IDs_Combined)}")
print(f"After removing duplicates: {len(combined_data['Detectid'])}")

combined_data['Detectid']

# %%
#Let's just do 6 for now
##Making the groups
z_025_035 = []
z_035_045 = []
z_045_055 = []
z_055_065 = []
z_065_075 = []
z_075_085 = []
z_085_096 = []

z_025_035_index = []
z_035_045_index = []
z_045_055_index = []
z_055_065_index = []
z_065_075_index = []
z_075_085_index = []
z_085_096_index = [] 


a = -1
for i in combined_data["z"]:
    a = a+1
    #print(i)
    if 0.25 <= i < 0.35:
        #print(i)
        z_025_035.append(i)
        z_025_035_index.append(a)
    if 0.35 <= i < 0.45:
        z_035_045.append(i)
        z_035_045_index.append(a)
    if 0.45 <= i < 0.55:
        z_045_055.append(i)
        z_045_055_index.append(a)
    if 0.55 <= i < 0.65:
        z_055_065.append(i)
        z_055_065_index.append(a)
    if 0.65 <= i < 0.75:
        z_065_075.append(i)
        z_065_075_index.append(a)
    if 0.75 <= i < 0.85:
        z_075_085.append(i)
        z_075_085_index.append(a)
    if 0.85<= i <= 0.96:
        z_085_096.append(i)
        z_085_096_index.append(a)
    else:
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 21
#      17 z_085_096_index = []
#      20 a = -1
# ---> 21 for i in combined_data["z"]:
#      22     a = a+1
#      23     #print(i)
#
# NameError: name 'combined_data' is not defined

# %%
test_a = np.hstack((z_025_035, z_035_045, z_045_055, z_055_065, z_065_075, z_075_085, z_085_096))
print(len(test_a))



for i in np.arange(len(combined_data["RA"][z_025_035_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_025_035_index][i], combined_data["DEC"][z_025_035_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                test_array.append(j["details"]["Mag"])
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       1 test_a = np.hstack((z_025_035, z_035_045, z_045_055, z_055_065, z_065_075, z_075_085, z_085_096))
#       2 print(len(test_a))
# ----> 6 for i in np.arange(len(combined_data["RA"][z_025_035_index])):
#       7
#       8 #for i in np.arange(10):
#       9     coord7 = SkyCoord(combined_data["RA"][z_025_035_index][i], combined_data["DEC"][z_025_035_index][i], unit = 'deg')
#      10     cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)
#
# NameError: name 'combined_data' is not defined

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_025_035_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_025_035_index][i], combined_data["DEC"][z_025_035_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_025_035_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_025_035_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_025_035_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_025_035_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_025_035_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_025_035_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_025_035_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_025_035_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_025_035_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_025_035_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
print(j['cutout'].__dict__)
# Out:
# {'data': array([[ 0.002742  , -0.38316327, -0.53624356, ..., -0.02768533,
#          0.12375301,  0.12676774],
#        [-1.1406817 ,  0.38595113,  0.10215045, ...,  0.31913742,
#          0.7945309 , -0.11241727],
#        [ 0.4423946 ,  0.02955259, -0.01321919, ..., -0.28725117,
#          0.02955501,  0.43219757],
#        ...,
#        [-0.3662405 , -0.1967579 ,  0.10864383, ..., -0.22209275,
#         -0.35525396, -0.08976366],
#        [-0.03597507,  0.39315403,  0.12565944, ..., -0.06900492,
#         -0.36219376,  0.53692716],
#        [-0.69498616,  0.5592662 , -0.2156052 , ..., -0.4258746 ,
#          0.29217574, -0.36236104]], dtype=float32), 'input_position_cutout': (41.800293089858314, 41.23342821044935), 'slices_original': (slice(3139, 3223, None), slice(3976, 4060, None)), 'slices_cutout': (slice(0, 84, None), slice(0, 84, None)), 'shape': (84, 84), 'input_position_original': (array(4017.80029309), array(3180.23342821)), 'shape_input': array([84, 84]), 'bbox_original': ((3139, 3222), (3976, 4059)), 'ymin_original': 3139, 'ymax_original': 3222, 'xmin_original': 3976, 'xmax_original': 4059, 'bbox_cutout': ((0, 83), (0, 83)), 'ymin_cutout': 0, 'ymax_cutout': 83, 'xmin_cutout': 0, 'xmax_cutout': 83, 'origin_original': (3976, 3139), '_origin_original_true': (3976, 3139), 'wcs': WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CRVAL : 22.2222222222222 -0.743801652892557
# CRPIX : 10124.0 -13039.0
# CD1_1 CD1_2  : -4.66666666666406e-05 0.0
# CD2_1 CD2_2  : 0.0 4.66666666666407e-05
# NAXIS : 84  84, 'center_cutout': (41.5, 41.5)}

# %%
print(cutouts7)
# Out:
# [{'cutout': <astropy.nddata.utils.Cutout2D object at 0x7f319f291a00>, 'hdu': [SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH variance_scale = 1.13043591153332
# BGMEAN  =    0.016247422212711
# BGVAR   =  0.00930391167383636
# HIERARCH EXPINFO_V =         1
# AR_HDU  =                    5 / HDU (1-indexed) containing the archive used to
# HIERARCH TRANSMISSION_CURVE_ID = 1 / archive ID for generic component 'TRANSMISS
# HIERARCH ARCHIVE_ID_TRANSMISSION_CURVE = 1 / archive ID for generic component 'T
# HIERARCH AP_CORR_MAP_ID =  438 / archive ID for generic component 'AP_CORR_MAP'
# HIERARCH ARCHIVE_ID_AP_CORR_MAP = 438 / archive ID for generic component 'AP_COR
# HIERARCH COADD_INPUTS_ID = 1819 / archive ID for generic component 'COADD_INPUTS
# HIERARCH ARCHIVE_ID_COADD_INPUTS = 1819 / archive ID for generic component 'COAD
# HIERARCH SKYWCS_ID =         2 / archive ID for generic component 'SKYWCS'
# HIERARCH ARCHIVE_ID_SKYWCS = 2 / archive ID for generic component 'SKYWCS'
# PSF_ID  =                 2058 / archive ID for generic component 'PSF'
# HIERARCH ARCHIVE_ID_PSF = 2058 / archive ID for generic component 'PSF'
# HIERARCH PHOTOCALIB_ID =  2060 / archive ID for generic component 'PHOTOCALIB'
# HIERARCH ARCHIVE_ID_PHOTOCALIB = 2060 / archive ID for generic component 'PHOTOC
# FILTER  = 'g       '                                                            , SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / data type of original image
# NAXIS   =                    2 / dimension of original image
# NAXIS1  =                 4200 / length of original image axis
# NAXIS2  =                 4200 / length of original image axis
# WCSAXES =                    2 / Number of WCS axes
# CRPIX1  =               14100. / Reference pixel on axis 1
# CRPIX2  =               -9900. / Reference pixel on axis 2
# CRVAL1  =     22.2222222222222 / Value at ref. pixel on axis 1
# CRVAL2  =   -0.743801652892557 / Value at ref. pixel on axis 2
# CTYPE1  = 'RA---TAN'           / Type of co-ordinate on axis 1
# CTYPE2  = 'DEC--TAN'           / Type of co-ordinate on axis 2
# CD1_1   = -4.66666666666406E-05 / Transformation matrix element
# CD2_2   = 4.66666666666407E-05 / Transformation matrix element
# RADESYS = 'ICRS    '           / Reference frame for RA/DEC values
# CD1_2   =                   0. / Transformation matrix element
# CD2_1   =                   0. / Transformation matrix element
# LTV1    =               -3900.
# LTV2    =              -27900.
# INHERIT =                    T
# EXTTYPE = 'IMAGE   '
# CTYPE1A = 'LINEAR  '           / Type of projection
# CTYPE2A = 'LINEAR  '           / Type of projection
# CRPIX1A =                   1. / Column Pixel Coordinate of Reference
# CRPIX2A =                   1. / Row Pixel Coordinate of Reference
# CRVAL1A =                3900. / Column pixel of Reference Pixel
# CRVAL2A =               27900. / Row pixel of Reference Pixel
# CUNIT1A = 'PIXEL   '           / Column unit
# CUNIT2A = 'PIXEL   '           / Row unit
# BSCALE  =                  1.0                                                  , SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                   32 / data type of original image
# NAXIS   =                    2 / dimension of original image
# NAXIS1  =                 4200 / length of original image axis
# NAXIS2  =                 4200 / length of original image axis
# WCSAXES =                    2 / Number of WCS axes
# CRPIX1  =               14100. / Reference pixel on axis 1
# CRPIX2  =               -9900. / Reference pixel on axis 2
# CRVAL1  =     22.2222222222222 / Value at ref. pixel on axis 1
# CRVAL2  =   -0.743801652892557 / Value at ref. pixel on axis 2
# CTYPE1  = 'RA---TAN'           / Type of co-ordinate on axis 1
# CTYPE2  = 'DEC--TAN'           / Type of co-ordinate on axis 2
# CD1_1   = -4.66666666666406E-05 / Transformation matrix element
# CD2_2   = 4.66666666666407E-05 / Transformation matrix element
# RADESYS = 'ICRS    '           / Reference frame for RA/DEC values
# CD1_2   =                   0. / Transformation matrix element
# CD2_1   =                   0. / Transformation matrix element
# LTV1    =               -3900.
# LTV2    =              -27900.
# INHERIT =                    T
# EXTTYPE = 'MASK    '
# MP_BAD  =                    0
# HIERARCH MP_BRIGHT_OBJECT =  9
# HIERARCH MP_CLIPPED =       14
# MP_CR   =                    3
# HIERARCH MP_CROSSTALK =     10
# HIERARCH MP_DETECTED =       5
# HIERARCH MP_DETECTED_NEGATIVE = 6
# MP_EDGE =                    4
# HIERARCH MP_INEXACT_PSF =   16
# MP_INTRP=                    2
# HIERARCH MP_NOT_DEBLENDED = 11
# HIERARCH MP_NO_DATA =        8
# HIERARCH MP_REJECTED =      13
# MP_SAT  =                    1
# HIERARCH MP_SENSOR_EDGE =   15
# HIERARCH MP_SUSPECT =        7
# HIERARCH MP_UNMASKEDNAN =   12
# CTYPE1A = 'LINEAR  '           / Type of projection
# CTYPE2A = 'LINEAR  '           / Type of projection
# CRPIX1A =                   1. / Column Pixel Coordinate of Reference
# CRPIX2A =                   1. / Row Pixel Coordinate of Reference
# CRVAL1A =                3900. / Column pixel of Reference Pixel
# CRVAL2A =               27900. / Row pixel of Reference Pixel
# CUNIT1A = 'PIXEL   '           / Column unit
# CUNIT2A = 'PIXEL   '           / Row unit                                       , SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / data type of original image
# NAXIS   =                    2 / dimension of original image
# NAXIS1  =                 4200 / length of original image axis
# NAXIS2  =                 4200 / length of original image axis
# WCSAXES =                    2 / Number of WCS axes
# CRPIX1  =               14100. / Reference pixel on axis 1
# CRPIX2  =               -9900. / Reference pixel on axis 2
# CRVAL1  =     22.2222222222222 / Value at ref. pixel on axis 1
# CRVAL2  =   -0.743801652892557 / Value at ref. pixel on axis 2
# CTYPE1  = 'RA---TAN'           / Type of co-ordinate on axis 1
# CTYPE2  = 'DEC--TAN'           / Type of co-ordinate on axis 2
# CD1_1   = -4.66666666666406E-05 / Transformation matrix element
# CD2_2   = 4.66666666666407E-05 / Transformation matrix element
# RADESYS = 'ICRS    '           / Reference frame for RA/DEC values
# CD1_2   =                   0. / Transformation matrix element
# CD2_1   =                   0. / Transformation matrix element
# LTV1    =               -3900.
# LTV2    =              -27900.
# INHERIT =                    T
# EXTTYPE = 'VARIANCE'
# CTYPE1A = 'LINEAR  '           / Type of projection
# CTYPE2A = 'LINEAR  '           / Type of projection
# CRPIX1A =                   1. / Column Pixel Coordinate of Reference
# CRPIX2A =                   1. / Row Pixel Coordinate of Reference
# CRVAL1A =                3900. / Column pixel of Reference Pixel
# CRVAL2A =               27900. / Row pixel of Reference Pixel
# CUNIT1A = 'PIXEL   '           / Column unit
# CUNIT2A = 'PIXEL   '           / Row unit
# BSCALE  =                  1.0                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                  148 / width of table in bytes
# NAXIS2  =                 2139 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    7 / number of fields in each row
# TTYPE1  = 'id      '           / Archive ID of the persistable object that owns
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'Archive ID of the persistable object that owns the records pointed &'
# CONTINUE  'at by this entry'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'cat.archive'        / index of the catalog this entry points to, from
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'index of the catalog this entry points to, from the perspective of &'
# CONTINUE  'the archive'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'cat.persistable'    / index of the catalog this entry points to, from
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'index of the catalog this entry points to, from the perspective of &'
# CONTINUE  'the Persistable'
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'row0    '           / first row used by the persistable object in thi
# TFORM4  = '1J      '           / format of field
# TDOC4   = 'first row used by the persistable object in this catalog'
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'nrows   '           / number of rows used by the persistable object i
# TFORM5  = '1J      '           / format of field
# TDOC5   = 'number of rows used by the persistable object in this catalog'
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'name    '           / unique name for the persistable object's class
# TFORM6  = '64A     '           / format of field
# TDOC6   = 'unique name for the persistable object''s class'
# TCCLS6  = 'String  '           / Field template used by lsst.afw.table
# TTYPE7  = 'module  '           / Python module that should be imported to regist
# TFORM7  = '64A     '           / format of field
# TDOC7   = 'Python module that should be imported to register the object''s fac&'
# CONTINUE  'tory    '
# TCCLS7  = 'String  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_INDEX'
# AR_CATN =                    0 / # of this catalog relative to the start of this
# AR_NCAT =                   26 / # of catalogs in this archive, including the in
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   36 / width of table in bytes
# NAXIS2  =                    1 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    5 / number of fields in each row
# TTYPE1  = 'coaddWcs'           / archive ID for the coadd's WCS
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID for the coadd''s WCS'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'wavelengthMin'      / getWavelengthBounds().min
# TFORM2  = '1D      '           / format of field
# TDOC2   = 'getWavelengthBounds().min'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'wavelengthMax'      / getWavelengthBounds().max
# TFORM3  = '1D      '           / format of field
# TDOC3   = 'getWavelengthBounds().max'
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'throughputAtMin'    / throughputAtBounds().first
# TFORM4  = '1D      '           / format of field
# TDOC4   = 'throughputAtBounds().first'
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'throughputAtMax'    / throughputAtBounds().second
# TFORM5  = '1D      '           / format of field
# TDOC5   = 'throughputAtBounds().second'
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    1 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddTransmissionCurve' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   16 / width of table in bytes
# NAXIS2  =                   37 / number of rows in table
# PCOUNT  =               522824 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    1 / number of fields in each row
# TTYPE1  = 'wcs     '           / wcs string representation
# TFORM1  = '1QB(17523)'         / format of field
# TDOC1   = 'wcs string representation'
# TCCLS1  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    2 / # of this catalog relative to the start of this
# AR_NAME = 'SkyWcs  '           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   52 / width of table in bytes
# NAXIS2  =                   29 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    8 / number of fields in each row
# TTYPE1  = 'transmission'       / archive ID for this sensor's TransmissionCurve
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID for this sensor''s TransmissionCurve'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'sensorWcs'          / archive ID for this sensor's WCS
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID for this sensor''s WCS'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'validPolygon'       / archive ID for this sensor's ValidPolygon
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'archive ID for this sensor''s ValidPolygon'
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'bbox_min_x'         / bounding box of the sensor (minimum)
# TFORM4  = '1D      '           / format of field
# TDOC4   = 'bounding box of the sensor (minimum)'
# TUNIT4  = 'pixel   '
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'bbox_min_y'         / bounding box of the sensor (minimum)
# TFORM5  = '1D      '           / format of field
# TDOC5   = 'bounding box of the sensor (minimum)'
# TUNIT5  = 'pixel   '
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'bbox_max_x'         / bounding box of the sensor (maximum)
# TFORM6  = '1D      '           / format of field
# TDOC6   = 'bounding box of the sensor (maximum)'
# TUNIT6  = 'pixel   '
# TCCLS6  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE7  = 'bbox_max_y'         / bounding box of the sensor (maximum)
# TFORM7  = '1D      '           / format of field
# TDOC7   = 'bounding box of the sensor (maximum)'
# TUNIT7  = 'pixel   '
# TCCLS7  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE8  = 'weight  '           / relative weight for this sensor in the average
# TFORM8  = '1D      '           / format of field
# TDOC8   = 'relative weight for this sensor in the average'
# TCCLS8  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    3 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddTransmissionCurve' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                    8 / width of table in bytes
# NAXIS2  =                  145 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    2 / number of fields in each row
# TTYPE1  = 'a       '           / archive ID of first operand
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID of first operand'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'b       '           / archive ID of second operand
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID of second operand'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    4 / # of this catalog relative to the start of this
# AR_NAME = 'ProductTransmissionCurve' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                    8 / width of table in bytes
# NAXIS2  =                   29 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    2 / number of fields in each row
# TTYPE1  = 'nested  '           / archive ID of the nested TransmissionCurve
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID of the nested TransmissionCurve'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'transform'          / archive ID of the coordinate transform
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID of the coordinate transform'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    5 / # of this catalog relative to the start of this
# AR_NAME = 'TransformedTransmissionCurve' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   48 / width of table in bytes
# NAXIS2  =                  145 / number of rows in table
# PCOUNT  =               772096 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    4 / number of fields in each row
# TTYPE1  = 'throughputAtMin'    / throughput below minimum wavelength
# TFORM1  = '1D      '           / format of field
# TDOC1   = 'throughput below minimum wavelength'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'throughputAtMax'    / throughput above minimum wavelength
# TFORM2  = '1D      '           / format of field
# TDOC2   = 'throughput above minimum wavelength'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'throughput'         / array of known throughput values
# TFORM3  = '1QD(1000)'          / format of field
# TDOC3   = 'array of known throughput values'
# TCCLS3  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE4  = 'wavelengths'        / array of known wavelength values
# TFORM4  = '1QD(1000)'          / format of field
# TDOC4   = 'array of known wavelength values'
# TUNIT4  = 'angstrom'
# TCCLS4  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    6 / # of this catalog relative to the start of this
# AR_NAME = 'SpatiallyConstantTransmissionCurve' / Class name for objects stored h
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   64 / width of table in bytes
# NAXIS2  =                   29 / number of rows in table
# PCOUNT  =              3270968 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    5 / number of fields in each row
# TTYPE1  = 'throughputAtMin'    / throughput below minimum wavelength
# TFORM1  = '1D      '           / format of field
# TDOC1   = 'throughput below minimum wavelength'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'throughputAtMax'    / throughput above minimum wavelength
# TFORM2  = '1D      '           / format of field
# TDOC2   = 'throughput above minimum wavelength'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'throughput'         / flattenned 2-d array of known throughput values
# TFORM3  = '1QD(13601)'         / format of field
# TDOC3   = 'flattenned 2-d array of known throughput values, with radius dimens&'
# CONTINUE  'ion fastest'
# TCCLS3  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE4  = 'wavelengths'        / array of known wavelength values
# TFORM4  = '1QD(469)'           / format of field
# TDOC4   = 'array of known wavelength values'
# TUNIT4  = 'angstrom'
# TCCLS4  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE5  = 'radii   '           / array of known radius values
# TFORM5  = '1QD(29) '           / format of field
# TDOC5   = 'array of known radius values'
# TCCLS5  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    7 / # of this catalog relative to the start of this
# AR_NAME = 'RadialTransmissionCurve' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   16 / width of table in bytes
# NAXIS2  =                   29 / number of rows in table
# PCOUNT  =                21164 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    1 / number of fields in each row
# TTYPE1  = 'bytes   '           / a bytestring containing the output of Transform
# TFORM1  = '1QB(734)'           / format of field
# TDOC1   = 'a bytestring containing the output of Transform.writeString'
# TCCLS1  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    8 / # of this catalog relative to the start of this
# AR_NAME = 'TransformPoint2ToPoint2' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   16 / width of table in bytes
# NAXIS2  =                  170 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    2 / number of fields in each row
# TTYPE1  = 'vertices_x'         / list of vertex points
# TFORM1  = '1D      '           / format of field
# TDOC1   = 'list of vertex points'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'vertices_y'         / list of vertex points
# TFORM2  = '1D      '           / format of field
# TDOC2   = 'list of vertex points'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                    9 / # of this catalog relative to the start of this
# AR_NAME = 'Polygon '           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   68 / width of table in bytes
# NAXIS2  =                 1380 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    2 / number of fields in each row
# TTYPE1  = 'name    '           / name of the aperture correction
# TFORM1  = '64A     '           / format of field
# TDOC1   = 'name of the aperture correction'
# TCCLS1  = 'String  '           / Field template used by lsst.afw.table
# TTYPE2  = 'field   '           / archive ID of the BoundedField object
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID of the BoundedField object'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   10 / # of this catalog relative to the start of this
# AR_NAME = 'ApCorrMap'          / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   29 / width of table in bytes
# NAXIS2  =                   46 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    7 / number of fields in each row
# TTYPE1  = 'flags   '           / bits for all Flag fields; see also TFLAGn
# TFORM1  = '1X      '           / format of field
# FLAGCOL =                    1 / Column number for the bitflags.
# TTYPE2  = 'bbox_min_x'         / lower-left corner of bounding box
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'lower-left corner of bounding box'
# TUNIT2  = 'pixel   '
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'bbox_min_y'         / lower-left corner of bounding box
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'lower-left corner of bounding box'
# TUNIT3  = 'pixel   '
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'bbox_max_x'         / upper-right corner of bounding box
# TFORM4  = '1J      '           / format of field
# TDOC4   = 'upper-right corner of bounding box'
# TUNIT4  = 'pixel   '
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'bbox_max_y'         / upper-right corner of bounding box
# TFORM5  = '1J      '           / format of field
# TDOC5   = 'upper-right corner of bounding box'
# TUNIT5  = 'pixel   '
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'coaddWcs'           / archive ID of the coadd's WCS
# TFORM6  = '1J      '           / format of field
# TDOC6   = 'archive ID of the coadd''s WCS'
# TCCLS6  = 'Scalar  '           / Field template used by lsst.afw.table
# TFLAG1  = 'throwOnMissing'
# TFDOC1  = 'whether to throw an exception on missing data'
# TTYPE7  = 'default '           / default value to use when throwOnMissing is Fal
# TFORM7  = '1D      '           / format of field
# TDOC7   = 'default value to use when throwOnMissing is False'
# TCCLS7  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   11 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddBoundedField'  / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   20 / width of table in bytes
# NAXIS2  =                 1334 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    4 / number of fields in each row
# TTYPE1  = 'field   '           / archive ID of the BoundedField to be coadded
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID of the BoundedField to be coadded'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'wcs     '           / archive ID of the Wcs associated with this elem
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID of the Wcs associated with this element'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'validPolygon'       / archive ID of the Polygon associated with this
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'archive ID of the Polygon associated with this element'
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'weight  '           / weight value for this element
# TFORM4  = '1D      '           / format of field
# TDOC4   = 'weight value for this element'
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   12 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddBoundedField'  / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   92 / width of table in bytes
# NAXIS2  =                  673 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    6 / number of fields in each row
# TTYPE1  = 'order_x '           / maximum Chebyshev function order in x
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'maximum Chebyshev function order in x'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'bbox_min_x'         / bounding box (minimum)
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'bounding box (minimum)'
# TUNIT2  = 'pixel   '
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'bbox_min_y'         / bounding box (minimum)
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'bounding box (minimum)'
# TUNIT3  = 'pixel   '
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'bbox_max_x'         / bounding box (maximum)
# TFORM4  = '1J      '           / format of field
# TDOC4   = 'bounding box (maximum)'
# TUNIT4  = 'pixel   '
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'bbox_max_y'         / bounding box (maximum)
# TFORM5  = '1J      '           / format of field
# TDOC5   = 'bounding box (maximum)'
# TUNIT5  = 'pixel   '
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'coefficients'       / Chebyshev function coefficients, ordered by y t
# TFORM6  = '9D      '           / format of field
# TDOC6   = 'Chebyshev function coefficients, ordered by y then x'
# TCCLS6  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   13 / # of this catalog relative to the start of this
# AR_NAME = 'ChebyshevBoundedField' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   52 / width of table in bytes
# NAXIS2  =                   52 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    6 / number of fields in each row
# TTYPE1  = 'order_x '           / maximum Chebyshev function order in x
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'maximum Chebyshev function order in x'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'bbox_min_x'         / bounding box (minimum)
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'bounding box (minimum)'
# TUNIT2  = 'pixel   '
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'bbox_min_y'         / bounding box (minimum)
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'bounding box (minimum)'
# TUNIT3  = 'pixel   '
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'bbox_max_x'         / bounding box (maximum)
# TFORM4  = '1J      '           / format of field
# TDOC4   = 'bounding box (maximum)'
# TUNIT4  = 'pixel   '
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'bbox_max_y'         / bounding box (maximum)
# TFORM5  = '1J      '           / format of field
# TDOC5   = 'bounding box (maximum)'
# TUNIT5  = 'pixel   '
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'coefficients'       / Chebyshev function coefficients, ordered by y t
# TFORM6  = '4D      '           / format of field
# TDOC6   = 'Chebyshev function coefficients, ordered by y then x'
# TCCLS6  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   14 / # of this catalog relative to the start of this
# AR_NAME = 'ChebyshevBoundedField' / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   28 / width of table in bytes
# NAXIS2  =                  668 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    6 / number of fields in each row
# TTYPE1  = 'order_x '           / maximum Chebyshev function order in x
# ...
# TCCLS7  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE8  = 'averagePosition_y'  / average position of stars used to make the PSF
# TFORM8  = '1D      '           / format of field
# TDOC8   = 'average position of stars used to make the PSF'
# TUNIT8  = 'pixel   '
# TCCLS8  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE9  = '_pixstep'           / oversampling
# TFORM9  = '1E      '           / format of field
# TDOC9   = 'oversampling'
# TUNIT9  = 'pixel   '
# TCCLS9  = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   22 / # of this catalog relative to the start of this
# AR_NAME = 'PsfexPsf'           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =               157616 / width of table in bytes
# NAXIS2  =                    9 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    8 / number of fields in each row
# TTYPE1  = 'group   '           / Groups (of coefficients?)
# TFORM1  = '2J      '           / format of field
# TDOC1   = 'Groups (of coefficients?)'
# TCCLS1  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE2  = 'degree  '           / Degree in each group
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'Degree in each group'
# TCCLS2  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE3  = 'basis   '           / Values of the basis functions
# TFORM3  = '6D      '           / format of field
# TDOC3   = 'Values of the basis functions'
# TCCLS3  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE4  = 'coeff   '           / Polynomial coefficients
# TFORM4  = '6D      '           / format of field
# TDOC4   = 'Polynomial coefficients'
# TCCLS4  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE5  = '_size   '           / PSF dimensions
# TFORM5  = '3J      '           / format of field
# TDOC5   = 'PSF dimensions'
# TCCLS5  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE6  = '_comp   '           / Complete pixel data
# TFORM6  = '39366E  '           / format of field
# TDOC6   = 'Complete pixel data'
# TCCLS6  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE7  = '_context_first'     / Offset to apply to context data
# TFORM7  = '2D      '           / format of field
# TDOC7   = 'Offset to apply to context data'
# TCCLS7  = 'Array   '           / Field template used by lsst.afw.table
# TTYPE8  = '_context_second'    / Scale to apply to context data
# TFORM8  = '2D      '           / format of field
# TDOC8   = 'Scale to apply to context data'
# TCCLS8  = 'Array   '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   23 / # of this catalog relative to the start of this
# AR_NAME = 'PsfexPsf'           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   56 / width of table in bytes
# NAXIS2  =                    1 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                    5 / number of fields in each row
# TTYPE1  = 'coaddwcs'           / archive ID of the coadd's WCS
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID of the coadd''s WCS'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'cachesize'          / size of the warping cache
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'size of the warping cache'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'avgpos_x'           / PSF accessors default position
# TFORM3  = '1D      '           / format of field
# TDOC3   = 'PSF accessors default position'
# TUNIT3  = 'pixel   '
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'avgpos_y'           / PSF accessors default position
# TFORM4  = '1D      '           / format of field
# TDOC4   = 'PSF accessors default position'
# TUNIT4  = 'pixel   '
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'warpingkernelname'  / warping kernel name
# TFORM5  = '32A     '           / format of field
# TDOC5   = 'warping kernel name'
# TCCLS5  = 'String  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   24 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddPsf'           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  , XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional binary table
# NAXIS1  =                   68 / width of table in bytes
# NAXIS2  =                    9 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# TFIELDS =                   15 / number of fields in each row
# TTYPE1  = 'wcs     '           / archive ID for Wcs object
# TFORM1  = '1J      '           / format of field
# TDOC1   = 'archive ID for Wcs object'
# TCCLS1  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE2  = 'psf     '           / archive ID for Psf object
# TFORM2  = '1J      '           / format of field
# TDOC2   = 'archive ID for Psf object'
# TCCLS2  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE3  = 'photoCalib'         / archive ID for PhotoCalib object
# TFORM3  = '1J      '           / format of field
# TDOC3   = 'archive ID for PhotoCalib object'
# TCCLS3  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE4  = 'apCorrMap'          / archive ID for ApCorrMap object
# TFORM4  = '1J      '           / format of field
# TDOC4   = 'archive ID for ApCorrMap object'
# TCCLS4  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE5  = 'validPolygon'       / archive ID for Polygon object
# TFORM5  = '1J      '           / format of field
# TDOC5   = 'archive ID for Polygon object'
# TCCLS5  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE6  = 'visitInfo'          / archive ID for VisitInfo object
# TFORM6  = '1J      '           / format of field
# TDOC6   = 'archive ID for VisitInfo object'
# TCCLS6  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE7  = 'transmissionCurve'  / archive ID for TransmissionCurve object
# TFORM7  = '1J      '           / format of field
# TDOC7   = 'archive ID for TransmissionCurve object'
# TCCLS7  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE8  = 'detector'           / archive ID for Detector object
# TFORM8  = '1J      '           / format of field
# TDOC8   = 'archive ID for Detector object'
# TCCLS8  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE9  = 'id      '           / unique ID
# TFORM9  = '1K      '           / format of field
# TDOC9   = 'unique ID'
# TCCLS9  = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE10 = 'bbox_min_x'         / bounding box (minimum)
# TFORM10 = '1J      '           / format of field
# TDOC10  = 'bounding box (minimum)'
# TUNIT10 = 'pixel   '
# TCCLS10 = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE11 = 'bbox_min_y'         / bounding box (minimum)
# TFORM11 = '1J      '           / format of field
# TDOC11  = 'bounding box (minimum)'
# TUNIT11 = 'pixel   '
# TCCLS11 = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE12 = 'bbox_max_x'         / bounding box (maximum)
# TFORM12 = '1J      '           / format of field
# TDOC12  = 'bounding box (maximum)'
# TUNIT12 = 'pixel   '
# TCCLS12 = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE13 = 'bbox_max_y'         / bounding box (maximum)
# TFORM13 = '1J      '           / format of field
# TDOC13  = 'bounding box (maximum)'
# TUNIT13 = 'pixel   '
# TCCLS13 = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE14 = 'goodpix '           / Number of good pixels in this CCD
# TFORM14 = '1J      '           / format of field
# TDOC14  = 'Number of good pixels in this CCD'
# TCCLS14 = 'Scalar  '           / Field template used by lsst.afw.table
# TTYPE15 = 'weight  '           / Coadd weight
# TFORM15 = '1D      '           / format of field
# TDOC15  = 'Coadd weight'
# TCCLS15 = 'Scalar  '           / Field template used by lsst.afw.table
# EXTTYPE = 'ARCHIVE_DATA'
# AR_CATN =                   25 / # of this catalog relative to the start of this
# AR_NAME = 'CoaddPsf'           / Class name for objects stored here
# HIERARCH AFW_TABLE_VERSION = 3                                                  ], 'path': '/home/jovyan/Hobby-Eberly-Telesco/imaging/hsc_ssp/w02/y/calexp-HSC-Y-9241-1,7.fits', 'filter': 'y', 'instrument': 'HSC SSP', 'mag': 18.493446875352394, 'aperture': 1.5747086344967909, 'ap_center': (0.0, 0.0), 'mag_limit': 24.7, 'details': {'catalog_name': 'HSC-SSP', 'filter_name': 'y', 'ra': 22.69234481490662, 'dec': -0.13355395749399696, 'radius': 1.5747086344967909, 'mag': 18.493446875352394, 'mag_err': 0.003424916428102165, 'mag_bright': 18.490032728737845, 'mag_faint': 18.496871791780496, 'pixel_scale': 0.16799999999990617, 'area_pix': None, 'sky_area_pix': None, 'aperture_counts': 2527.093146032, 'sky_counts': None, 'sky_average': None, 'aperture_eqw_rest_lya': None, 'aperture_eqw_rest_lya_err': None, 'aperture_plae': None, 'elixer_apertures': [{'idx': 0, 'ra': 22.6926562225638, 'dec': -0.13335025712145007, 'radius': 1.5, 'area_pix': 250.4458429203844, 'aperture_counts': 1498.3506503248254, 'sky_area_pix': 1248, 'sky_average': 0.09556861243494447, 'sky_counts': 23.934761698001196, 'sky_err': 0.018292333734068512, 'mag': 19.060966348299473, 'mag_err': 0.003324746845137838, 'mag_bright': 19.057651751437355, 'mag_faint': 19.06429109514461, 'selected': False}], 'elixer_aper_idx': 0, 'sep_objects': [{'idx': 0, 'x': 1.121281814935132, 'y': -0.733407831413521, 'ra': 22.69234481490662, 'dec': -0.13355395749399696, 'a': 3.3478060226421733, 'b': 2.9627849006636287, 'theta': -0.05390556529164314, 'background': 0.042234256863594055, 'background_rms': 0.41246965527534485, 'dist_baryctr': 1.3398357942982817, 'dist_curve': -1.0, 'flux_cts': 2527.093146032, 'flux_cts_err': 7.95906598649671, 'flags': 0, 'mag': 18.493446875352394, 'mag_faint': 18.496871791780496, 'mag_bright': 18.490032728737845, 'mag_err': 0.003424916428102165, 'selected': True, 'fixed_aper_radius': 1.0, 'fixed_aper_flux_cts': 2001.7454028129578, 'fixed_aper_flux_cts_err': 4.365168587617732, 'fixed_aper_flags': 0, 'fixed_aper_mag': 18.74647790053925, 'fixed_aper_mag_bright': 18.744112833790346, 'fixed_aper_mag_faint': 18.748848130378395, 'fixed_aper_mag_err': 0.0023702298391441445}], 'sep_obj_idx': 0, 'fail_mag_limit': False, 'raw_mag': None, 'raw_mag_bright': None, 'raw_mag_faint': None, 'raw_mag_err': None, 'exptime': None, 'mag_limit': 24.7}}]

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii], 
                 names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %% [markdown]
# print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_025_035_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(R_Mag_Array)
print("")
print(R_Mag_Err_Array)
# Out:
# [18.011472050175854, 18.73735362282975, 20.66806915651316, 17.8105480393359, 18.58951855411472, 20.292339039537186, 18.882336240156338, 18.49644518096239, 18.848540309989673, 18.5835479372022, 18.366843305420755, 18.782065867584365, 19.669652430509068, 20.746260676200997, 18.145825390967154, 18.970078253922317, 18.519500634168114, 18.802370604472472, 19.93690675191245, 18.8640741940171, 17.721426188232442, 19.474669953806583, 18.799153654984362, 18.84612549903682, 18.916973177329492, 19.68562925747125, 20.853295009308717, 26.4, 20.182172334716125, 19.69951259107543, 20.172798849472457, 19.016947976111364, 19.35433915448838, 18.590590934162055, 18.314097727188496, 18.489317456601285, 18.367494778711887, 26.4, 18.317804600783024, 18.589577540797, 18.50625835476189, 18.58502671995167, 19.615953927220115, 18.853381857655652, 18.86488752496099, 17.725298805242776, 18.011472050175854, 19.052934137425044, 20.746042733030386, 18.146754432164443, 18.8815319345155]
#
# [0.0005253428068598964, 0.001658220825667911, 0.004329573005950493, 0.0008761896468456598, 0.001206526864727664, 0.0030273627920323065, 0.0007484417557250822, 0.0007700608208942583, 0.0014066757991528789, 0.0018602664776530276, 0.0006377781273307903, 0.0012302088752846885, 0.002222817699848889, 0.002981261997515361, 0.0005334824538110183, 0.0021785592701561995, 0.001651859035444403, 0.0012186394631896746, 0.00353053247417634, 0.0004836088001169969, 0.0003027739006142838, 0.0013712661835434403, 0.0009157444838372442, 0.0019091705913609758, 0.0025278697137771644, 0.0027414896299085, 0.005733905817614016, 0.0, 0.006214342387128369, 0.0016332296160364024, 0.0029686747221617793, 0.0018789988618941322, 0.0009723188289640916, 0.0006325513614306999, 0.0006295803409557266, 0.0008025465251648711, 0.0006460988838199455, 0.0, 0.0005973799912588618, 0.0006688585367946587, 0.0017161694970866392, 0.0011983907434327534, 0.0027784219521898024, 0.0013741232250268354, 0.0004742825864916256, 0.00027730608661613587, 0.0005253428068598964, 0.002073739347409287, 0.0029788537008279548, 0.0005201479544183485, 0.0007176429052222488]

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_025_035_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_025_035_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_025_035_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_025_035_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_035_045_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_035_045_index][i], combined_data["DEC"][z_035_045_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_035_045_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_035_045_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_035_045_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_035_045_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_035_045_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_035_045_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_035_045_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_035_045_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_035_045_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_035_045_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_035_045_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_035_045_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_035_045_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_035_045_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_035_045_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_045_055_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_045_055_index][i], combined_data["DEC"][z_045_055_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_045_055_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_045_055_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_045_055_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_045_055_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_045_055_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_045_055_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_045_055_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_045_055_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_045_055_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_045_055_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_045_055_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))
# Out:
# 80 80 63 80 55

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_045_055_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_045_055_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_045_055_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_045_055_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_055_065_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_055_065_index][i], combined_data["DEC"][z_055_065_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_055_065_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_055_065_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_055_065_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_055_065_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_055_065_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_055_065_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_055_065_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_055_065_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_055_065_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_055_065_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_055_065_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))
# Out:
# 81 81 68 80 51

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_055_065_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_055_065_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_055_065_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_055_065_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_065_075_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_065_075_index][i], combined_data["DEC"][z_065_075_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_065_075_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_065_075_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_065_075_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_065_075_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_065_075_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_065_075_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_065_075_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_065_075_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_065_075_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_065_075_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_065_075_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))
# Out:
# 86 86 77 86 69

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_065_075_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_065_075_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_065_075_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_065_075_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_075_085_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_075_085_index][i], combined_data["DEC"][z_075_085_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_075_085_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_075_085_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_075_085_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_075_085_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_075_085_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_075_085_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_075_085_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_075_085_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_075_085_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_075_085_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_075_085_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))
# Out:
# 117 117 95 116 71

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_075_085_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_075_085_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_075_085_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_075_085_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %%
G_Data_Array = []
G_RA_Array = []
G_DEC_Array = []
G_Detect_ID = []
G_Redshift_Array = []
G_Redshift_Err_Array = []
G_Mag_Array = []
G_Mag_Err_Array = []
G_Aperture_Array = []
G_WCS_Array = []

R_Data_Array = []
R_RA_Array = []
R_DEC_Array = []
R_Detect_ID = []
R_Redshift_Array = []
R_Redshift_Err_Array = []
R_Mag_Array = []
R_Mag_Err_Array = []
R_Aperture_Array = []
R_WCS_Array = []

I_Data_Array = []
I_RA_Array = []
I_DEC_Array = []
I_Detect_ID = []
I_Redshift_Array = []
I_Redshift_Err_Array = []
I_Mag_Array = []
I_Mag_Err_Array = []
I_Aperture_Array = []
I_WCS_Array = []

Z_Data_Array = []
Z_RA_Array = []
Z_DEC_Array = []
Z_Detect_ID = []
Z_Redshift_Array = []
Z_Redshift_Err_Array = []
Z_Mag_Array = []
Z_Mag_Err_Array = []
Z_Aperture_Array = []
Z_WCS_Array = []

Y_Data_Array = []
Y_RA_Array = []
Y_DEC_Array = []
Y_Detect_ID = []
Y_Redshift_Array = []
Y_Redshift_Err_Array = []
Y_Mag_Array = []
Y_Mag_Err_Array = []
Y_Aperture_Array = []
Y_WCS_Array = []



for i in np.arange(len(combined_data["RA"][z_085_096_index])): 

#for i in np.arange(10): 
    coord7 = SkyCoord(combined_data["RA"][z_085_096_index][i], combined_data["DEC"][z_085_096_index][i], unit = 'deg')
    cutouts7 = catlib.get_cutouts(position=coord7,radius=7.,aperture=1.5,dynamic=False,first=False,nudge=False,filter=None)

    #print(cutouts7)
    if len(cutouts7) > 0:
        cutout = cutouts7[0] 
        #print(cutout['instrument'])
        
        if cutout['instrument'] == "HSC SSP":
            for j in cutouts7:
                #print(j['details']["filter_name"])
                
                if j['details']["filter_name"] == "g":
                    #print("g")
                    #print(j['cutout'].error)
                    G_Data_Array.append(j['cutout'].data)
                    G_RA_Array.append(j['details']['ra'])
                    G_DEC_Array.append(j['details']['dec'])
                    G_Detect_ID.append(combined_data["Detectid"][z_085_096_index][i])
                    G_Redshift_Array.append(combined_data["z"][z_085_096_index][i])
                    G_Mag_Array.append(j['details']['mag'])
                    G_Mag_Err_Array.append(j['details']['mag_err'])
                    G_Aperture_Array.append(j['aperture'])
                    G_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "r":
                    #print("r")
                    R_Data_Array.append(j['cutout'].data)
                    R_RA_Array.append(j['details']['ra'])
                    R_DEC_Array.append(j['details']['dec'])
                    R_Detect_ID.append(combined_data["Detectid"][z_085_096_index][i])
                    R_Redshift_Array.append(combined_data["z"][z_085_096_index][i])
                    R_Mag_Array.append(j['details']['mag'])
                    R_Mag_Err_Array.append(j['details']['mag_err'])
                    R_Aperture_Array.append(j['aperture'])
                    R_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "i":
                    I_Data_Array.append(j['cutout'].data)
                    I_RA_Array.append(j['details']['ra'])
                    I_DEC_Array.append(j['details']['dec'])
                    I_Detect_ID.append(combined_data["Detectid"][z_085_096_index][i])
                    I_Redshift_Array.append(combined_data["z"][z_085_096_index][i])
                    I_Mag_Array.append(j['details']['mag'])
                    I_Mag_Err_Array.append(j['details']['mag_err'])
                    I_Aperture_Array.append(j['aperture'])
                    I_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "z":
                    Z_Data_Array.append(j['cutout'].data)
                    Z_RA_Array.append(j['details']['ra'])
                    Z_DEC_Array.append(j['details']['dec'])
                    Z_Detect_ID.append(combined_data["Detectid"][z_085_096_index][i])
                    Z_Redshift_Array.append(combined_data["z"][z_085_096_index][i])
                    Z_Mag_Array.append(j['details']['mag'])
                    Z_Mag_Err_Array.append(j['details']['mag_err'])
                    Z_Aperture_Array.append(j['aperture'])
                    Z_WCS_Array.append(j['cutout'].wcs)

                elif j['details']["filter_name"] == "y":
                    Y_Data_Array.append(j['cutout'].data)
                    Y_RA_Array.append(j['details']['ra'])
                    Y_DEC_Array.append(j['details']['dec'])
                    Y_Detect_ID.append(combined_data["Detectid"][z_085_096_index][i])
                    Y_Redshift_Array.append(combined_data["z"][z_085_096_index][i])
                    Y_Mag_Array.append(j['details']['mag'])
                    Y_Mag_Err_Array.append(j['details']['mag_err'])
                    Y_Aperture_Array.append(j['aperture'])
                    Y_WCS_Array.append(j['cutout'].wcs)

# %%
Table_start_a = ([(G_Data_Array[0])])
Table_start_b = ([(G_RA_Array[0])])
Table_start_c = ([(G_DEC_Array[0])])
Table_start_d = ([(G_Detect_ID[0])])
Table_start_e = ([(G_Redshift_Array[0])])
Table_start_f = ([(G_Mag_Array[0])])
Table_start_g = ([(G_Mag_Err_Array[0])])
Table_start_h = ([(G_Aperture_Array[0])])
Table_start_ii = ([(G_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("G_Data","G_RA","G_DEC", "G_Detect_ID", "G_Z", "G_Mag", "G_Mag_Err", "G_Aperture_Array", "G_WCS_str"))

# %%
for i in np.arange(1,len(G_RA_Array),1):
    a = ([(G_Data_Array[i])])
    b = ([(G_RA_Array[i])])
    c = ([(G_DEC_Array[i])])
    d = ([(G_Detect_ID[i])])
    e = ([(G_Redshift_Array[i])])
    f = ([(G_Mag_Array[i])])
    g = ([(G_Mag_Err_Array[i])])
    h = ([(G_Aperture_Array[i])])
    ii = ([(G_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_085_096_G.fits", overwrite = True)

# %%
Table_start_a = ([(R_Data_Array[0])])
Table_start_b = ([(R_RA_Array[0])])
Table_start_c = ([(R_DEC_Array[0])])
Table_start_d = ([(R_Detect_ID[0])])
Table_start_e = ([(R_Redshift_Array[0])])
Table_start_f = ([(R_Mag_Array[0])])
Table_start_g = ([(R_Mag_Err_Array[0])])
Table_start_h = ([(R_Aperture_Array[0])])
Table_start_ii = ([(R_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("R_Data","R_RA","R_DEC", "R_Detect_ID", "R_Z", "R_Mag", "R_Mag_Err", "R_Aperture_Array", "R_WCS_str"))

# %%
print(len(G_Data_Array), len(R_Data_Array), len(I_Data_Array), len(Z_Data_Array), len(Y_Data_Array))
# Out:
# 146 146 127 146 100

# %%
for i in np.arange(1,len(R_RA_Array),1):
    a = ([(R_Data_Array[i])])
    b = ([(R_RA_Array[i])])
    c = ([(R_DEC_Array[i])])
    d = ([(R_Detect_ID[i])])
    e = ([(R_Redshift_Array[i])])
    f = ([(R_Mag_Array[i])])
    g = ([(R_Mag_Err_Array[i])])
    h = ([(R_Aperture_Array[i])])
    ii = ([(R_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_085_096_R.fits", overwrite = True)

# %%
Table_start_a = ([(I_Data_Array[0])])
Table_start_b = ([(I_RA_Array[0])])
Table_start_c = ([(I_DEC_Array[0])])
Table_start_d = ([(I_Detect_ID[0])])
Table_start_e = ([(I_Redshift_Array[0])])
Table_start_f = ([(I_Mag_Array[0])])
Table_start_g = ([(I_Mag_Err_Array[0])])
Table_start_h = ([(I_Aperture_Array[0])])
Table_start_ii = ([(I_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("I_Data","I_RA","I_DEC", "I_Detect_ID", "I_Z", "I_Mag", "I_Mag_Err", "I_Aperture_Array", "I_WCS_str"))

# %%
for i in np.arange(1,len(I_RA_Array),1):
    a = ([(I_Data_Array[i])])
    b = ([(I_RA_Array[i])])
    c = ([(I_DEC_Array[i])])
    d = ([(I_Detect_ID[i])])
    e = ([(I_Redshift_Array[i])])
    f = ([(I_Mag_Array[i])])
    g = ([(I_Mag_Err_Array[i])])
    h = ([(I_Aperture_Array[i])])
    ii = ([(I_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_085_096_I.fits", overwrite = True)

# %%
Table_start_a = ([(Z_Data_Array[0])])
Table_start_b = ([(Z_RA_Array[0])])
Table_start_c = ([(Z_DEC_Array[0])])
Table_start_d = ([(Z_Detect_ID[0])])
Table_start_e = ([(Z_Redshift_Array[0])])
Table_start_f = ([(Z_Mag_Array[0])])
Table_start_g = ([(Z_Mag_Err_Array[0])])
Table_start_h = ([(Z_Aperture_Array[0])])
Table_start_ii = ([(Z_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Z_Data","Z_RA","Z_DEC", "Z_Detect_ID", "Z_Z", "Z_Mag", "Z_Mag_Err", "Z_Aperture_Array", "Z_WCS_str"))

# %%
for i in np.arange(1,len(Z_RA_Array),1):
    a = ([(Z_Data_Array[i])])
    b = ([(Z_RA_Array[i])])
    c = ([(Z_DEC_Array[i])])
    d = ([(Z_Detect_ID[i])])
    e = ([(Z_Redshift_Array[i])])
    f = ([(Z_Mag_Array[i])])
    g = ([(Z_Mag_Err_Array[i])])
    h = ([(Z_Aperture_Array[i])])
    ii = ([(Z_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_085_096_Z.fits", overwrite = True)

# %%
Table_start_a = ([(Y_Data_Array[0])])
Table_start_b = ([(Y_RA_Array[0])])
Table_start_c = ([(Y_DEC_Array[0])])
Table_start_d = ([(Y_Detect_ID[0])])
Table_start_e = ([(Y_Redshift_Array[0])])
Table_start_f = ([(Y_Mag_Array[0])])
Table_start_g = ([(Y_Mag_Err_Array[0])])
Table_start_h = ([(Y_Aperture_Array[0])])
Table_start_ii = ([(Y_WCS_Array[0].to_header().tostring())])

Table_b = QTable([Table_start_a, Table_start_b, Table_start_c, Table_start_d, Table_start_e, Table_start_f, Table_start_g, Table_start_h, Table_start_ii]
, names=("Y_Data","Y_RA","Y_DEC", "Y_Detect_ID", "Y_Z", "Y_Mag", "Y_Mag_Err", "Y_Aperture_Array", "Y_WCS_str"))

# %%
for i in np.arange(1,len(Y_RA_Array),1):
    a = ([(Y_Data_Array[i])])
    b = ([(Y_RA_Array[i])])
    c = ([(Y_DEC_Array[i])])
    d = ([(Y_Detect_ID[i])])
    e = ([(Y_Redshift_Array[i])])
    f = ([(Y_Mag_Array[i])])
    g = ([(Y_Mag_Err_Array[i])])
    h = ([(Y_Aperture_Array[i])])
    ii = ([(Y_WCS_Array[i].to_header().tostring())])

    Table_b.add_row([a,b,c,d,e,f,g,h,ii])

# %%
Table_b.write("/home/jovyan/work/stampede3/AGN-Black-Hole-Research/AGN-Black-Hole-Research-Full-Catalog/Table_Filters_New_Catalog_085_096_Y.fits", overwrite = True)

# %% [markdown]
# <hr style="border:4px solid blue">

# %% [markdown]
# ## <font color='#e55730' size=3 >Opening Files</font>

# %%
G_File_Filters_025_035 = "Table_Filters_New_Catalog_025_035_G.fits"
R_File_Filters_025_035 = "Table_Filters_New_Catalog_025_035_R.fits"
I_File_Filters_025_035 = "Table_Filters_New_Catalog_025_035_I.fits"
Z_File_Filters_025_035 = "Table_Filters_New_Catalog_025_035_Z.fits"
Y_File_Filters_025_035 = "Table_Filters_New_Catalog_025_035_Y.fits"



G_File_Filters_035_045 = "Table_Filters_New_Catalog_035_045_G.fits"
R_File_Filters_035_045 = "Table_Filters_New_Catalog_035_045_R.fits"
I_File_Filters_035_045 = "Table_Filters_New_Catalog_035_045_I.fits"
Z_File_Filters_035_045 = "Table_Filters_New_Catalog_035_045_Z.fits"
Y_File_Filters_035_045 = "Table_Filters_New_Catalog_035_045_Y.fits"


G_File_Filters_045_055 = "Table_Filters_New_Catalog_045_055_G.fits"
R_File_Filters_045_055 = "Table_Filters_New_Catalog_045_055_R.fits"
I_File_Filters_045_055 = "Table_Filters_New_Catalog_045_055_I.fits"
Z_File_Filters_045_055 = "Table_Filters_New_Catalog_045_055_Z.fits"
Y_File_Filters_045_055 = "Table_Filters_New_Catalog_045_055_Y.fits"

G_File_Filters_055_065 = "Table_Filters_New_Catalog_055_065_G.fits"
R_File_Filters_055_065 = "Table_Filters_New_Catalog_055_065_R.fits"
I_File_Filters_055_065 = "Table_Filters_New_Catalog_055_065_I.fits"
Z_File_Filters_055_065 = "Table_Filters_New_Catalog_055_065_Z.fits"
Y_File_Filters_055_065 = "Table_Filters_New_Catalog_055_065_Y.fits"

G_File_Filters_065_075 = "Table_Filters_New_Catalog_065_075_G.fits"
R_File_Filters_065_075 = "Table_Filters_New_Catalog_065_075_R.fits"
I_File_Filters_065_075 = "Table_Filters_New_Catalog_065_075_I.fits"
Z_File_Filters_065_075 = "Table_Filters_New_Catalog_065_075_Z.fits"
Y_File_Filters_065_075 = "Table_Filters_New_Catalog_065_075_Y.fits"

G_File_Filters_075_085 = "Table_Filters_New_Catalog_075_085_G.fits"
R_File_Filters_075_085 = "Table_Filters_New_Catalog_075_085_R.fits"
I_File_Filters_075_085 = "Table_Filters_New_Catalog_075_085_I.fits"
Z_File_Filters_075_085 = "Table_Filters_New_Catalog_075_085_Z.fits"
Y_File_Filters_075_085 = "Table_Filters_New_Catalog_075_085_Y.fits"

G_File_Filters_085_096 = "Table_Filters_New_Catalog_085_096_G.fits"
R_File_Filters_085_096 = "Table_Filters_New_Catalog_085_096_R.fits"
I_File_Filters_085_096 = "Table_Filters_New_Catalog_085_096_I.fits"
Z_File_Filters_085_096 = "Table_Filters_New_Catalog_085_096_Z.fits"
Y_File_Filters_085_096 = "Table_Filters_New_Catalog_085_096_Y.fits"

# %%
G_Filters_025_035 = Table.read(G_File_Filters_025_035, format = 'fits')
R_Filters_025_035 = Table.read(R_File_Filters_025_035, format = 'fits')
I_Filters_025_035 = Table.read(I_File_Filters_025_035, format = 'fits')
Z_Filters_025_035 = Table.read(Z_File_Filters_025_035, format = 'fits')
Y_Filters_025_035 = Table.read(Y_File_Filters_025_035, format = 'fits')


G_Filters_035_045 = Table.read(G_File_Filters_035_045, format = 'fits')
R_Filters_035_045 = Table.read(R_File_Filters_035_045, format = 'fits')
I_Filters_035_045 = Table.read(I_File_Filters_035_045, format = 'fits')
Z_Filters_035_045 = Table.read(Z_File_Filters_035_045, format = 'fits')
Y_Filters_035_045 = Table.read(Y_File_Filters_035_045, format = 'fits')


G_Filters_045_055 = Table.read(G_File_Filters_045_055, format = 'fits')
R_Filters_045_055 = Table.read(R_File_Filters_045_055, format = 'fits')
I_Filters_045_055 = Table.read(I_File_Filters_045_055, format = 'fits')
Z_Filters_045_055 = Table.read(Z_File_Filters_045_055, format = 'fits')
Y_Filters_045_055 = Table.read(Y_File_Filters_045_055, format = 'fits')


G_Filters_055_065 = Table.read(G_File_Filters_055_065, format = 'fits')
R_Filters_055_065 = Table.read(R_File_Filters_055_065, format = 'fits')
I_Filters_055_065 = Table.read(I_File_Filters_055_065, format = 'fits')
Z_Filters_055_065 = Table.read(Z_File_Filters_055_065, format = 'fits')
Y_Filters_055_065 = Table.read(Y_File_Filters_055_065, format = 'fits')


G_Filters_065_075 = Table.read(G_File_Filters_065_075, format = 'fits')
R_Filters_065_075 = Table.read(R_File_Filters_065_075, format = 'fits')
I_Filters_065_075 = Table.read(I_File_Filters_065_075, format = 'fits')
Z_Filters_065_075 = Table.read(Z_File_Filters_065_075, format = 'fits')
Y_Filters_065_075 = Table.read(Y_File_Filters_065_075, format = 'fits')


G_Filters_075_085 = Table.read(G_File_Filters_075_085, format = 'fits')
R_Filters_075_085 = Table.read(R_File_Filters_075_085, format = 'fits')
I_Filters_075_085 = Table.read(I_File_Filters_075_085, format = 'fits')
Z_Filters_075_085 = Table.read(Z_File_Filters_075_085, format = 'fits')
Y_Filters_075_085 = Table.read(Y_File_Filters_075_085, format = 'fits')

G_Filters_085_096 = Table.read(G_File_Filters_085_096, format = 'fits')
R_Filters_085_096 = Table.read(R_File_Filters_085_096, format = 'fits')
I_Filters_085_096 = Table.read(I_File_Filters_085_096, format = 'fits')
Z_Filters_085_096 = Table.read(Z_File_Filters_085_096, format = 'fits')
Y_Filters_085_096 = Table.read(Y_File_Filters_085_096, format = 'fits')

# %%
G_Filters_025_035 = Table(G_Filters_025_035)
R_Filters_025_035 = Table(R_Filters_025_035)
I_Filters_025_035 = Table(I_Filters_025_035)
Z_Filters_025_035 = Table(Z_Filters_025_035)
Y_Filters_025_035 = Table(Y_Filters_025_035)

G_Filters_035_045 = Table(G_Filters_035_045)
R_Filters_035_045 = Table(R_Filters_035_045)
I_Filters_035_045 = Table(I_Filters_035_045)
Z_Filters_035_045 = Table(Z_Filters_035_045)
Y_Filters_035_045 = Table(Y_Filters_035_045)


G_Filters_045_055 = Table(G_Filters_045_055)
R_Filters_045_055 = Table(R_Filters_045_055)
I_Filters_045_055 = Table(I_Filters_045_055)
Z_Filters_045_055 = Table(Z_Filters_045_055)
Y_Filters_045_055 = Table(Y_Filters_045_055)


G_Filters_055_065 = Table(G_Filters_055_065)
R_Filters_055_065 = Table(R_Filters_055_065)
I_Filters_055_065 = Table(I_Filters_055_065)
Z_Filters_055_065 = Table(Z_Filters_055_065)
Y_Filters_055_065 = Table(Y_Filters_055_065)


G_Filters_065_075 = Table(G_Filters_065_075)
R_Filters_065_075 = Table(R_Filters_065_075)
I_Filters_065_075 = Table(I_Filters_065_075)
Z_Filters_065_075 = Table(Z_Filters_065_075)
Y_Filters_065_075 = Table(Y_Filters_065_075)


G_Filters_075_085 = Table(G_Filters_075_085)
R_Filters_075_085 = Table(R_Filters_075_085)
I_Filters_075_085 = Table(I_Filters_075_085)
Z_Filters_075_085 = Table(Z_Filters_075_085)
Y_Filters_075_085 = Table(Y_Filters_075_085)


G_Filters_085_096 = Table(G_Filters_085_096)
R_Filters_085_096 = Table(R_Filters_085_096)
I_Filters_085_096 = Table(I_Filters_085_096)
Z_Filters_085_096 = Table(Z_Filters_085_096)
Y_Filters_085_096 = Table(Y_Filters_085_096)
G_Filters_025_035[0]
# Out:
# <Row index=0>
#            I_Data                  I_RA               I_DEC         I_Detect_ID   I_Z         I_Mag             I_Mag_Err        I_Aperture_Array                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      I_WCS_str
#        float32[84,84]            float64             float64           int64    float64      float64             float64             float64                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           bytes2880
# --------------------------- ------------------ -------------------- ----------- ------- ----------------- --------------------- ----------------- -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -0.016493104 .. -0.03243714 34.218650148149536 -0.39316264384412586  2190046583   0.304 17.65608897924027 0.0004841333866814068 2.784022613819336 WCSAXES =                    2 / Number of coordinate axes                      CRPIX1  =               3139.0 / Pixel coordinate of reference point            CRPIX2  =              -7474.0 / Pixel coordinate of reference point            PC1_1   = -4.6666666666639E-05 / Coordinate transformation matrix element       PC2_2   =  4.6666666666637E-05 / Coordinate transformation matrix element       CDELT1  =                  1.0 / [deg] Coordinate increment at reference point  CDELT2  =                  1.0 / [deg] Coordinate increment at reference point  CUNIT1  = 'deg'                / Units of coordinate increment and value        CUNIT2  = 'deg'                / Units of coordinate increment and value        CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection           CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection               CRVAL1  =      34.074074074074 / [deg] Coordinate value at reference point      CRVAL2  =    -0.74380165289256 / [deg] Coordinate value at reference point      LONPOLE =                180.0 / [deg] Native longitude of celestial pole       LATPOLE =    -0.74380165289256 / [deg] Native latitude of celestial pole        MJDREF  =                  0.0 / [d] MJD of fiducial time                       RADESYS = 'ICRS'               / Equatorial coordinate system                   END

# %%
G_Data_025_035 = G_Filters_025_035["G_Data"]
G_RA_025_035 = G_Filters_025_035["G_RA"]
G_DEC_025_035 = G_Filters_025_035["G_DEC"]
G_Detect_ID_025_035 = G_Filters_025_035["G_Detect_ID"]
G_Z_025_035 = G_Filters_025_035["G_Z"]

R_Data_025_035 = R_Filters_025_035["G_Data"]
R_RA_025_035 = R_Filters_025_035["G_RA"]
R_DEC_025_035 = R_Filters_025_035["G_DEC"]
R_Detect_ID_025_035 = R_Filters_025_035["G_Detect_ID"]
R_Z_025_035 = R_Filters_025_035["G_Z"]

I_Data_025_035 = I_Filters_025_035["G_Data"]
I_RA_025_035 = I_Filters_025_035["G_RA"]
I_DEC_025_035 = I_Filters_025_035["G_DEC"]
I_Detect_ID_025_035 = I_Filters_025_035["G_Detect_ID"]
I_Z_025_035 = I_Filters_025_035["G_Z"]

Z_Data_025_035 = Z_Filters_025_035["G_Data"]
Z_RA_025_035 = Z_Filters_025_035["G_RA"]
Z_DEC_025_035 = Z_Filters_025_035["G_DEC"]
Z_Detect_ID_025_035 = Z_Filters_025_035["G_Detect_ID"]
Z_Z_025_035 = Z_Filters_025_035["G_Z"]

Y_Data_025_035 = Y_Filters_025_035["G_Data"]
Y_RA_025_035 = Y_Filters_025_035["G_RA"]
Y_DEC_025_035 = Y_Filters_025_035["G_DEC"]
Y_Detect_ID_025_035 = Y_Filters_025_035["G_Detect_ID"]
Y_Z_025_035 = Y_Filters_025_035["G_Z"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 G_Data_025_035 = G_Filters_025_035["G_Data"]
#       2 G_RA_025_035 = G_Filters_025_035["G_RA"]
#       3 G_DEC_025_035 = G_Filters_025_035["G_DEC"]
#
# File /opt/conda/lib/python3.12/site-packages/astropy/table/table.py:2093, in Table.__getitem__(self, item)
#    2091 def __getitem__(self, item):
#    2092     if isinstance(item, str):
# -> 2093         return self.columns[item]
#    2094     elif isinstance(item, (int, np.integer)):
#    2095         return self.Row(self, item)
#
# File /opt/conda/lib/python3.12/site-packages/astropy/table/table.py:264, in TableColumns.__getitem__(self, item)
#     253 """Get items from a TableColumns object.
#     254
#     255 ::
#    (...)
#     261   tc[1:3] # <TableColumns names=('b', 'c')>
#     262 """
#     263 if isinstance(item, str):
# --> 264     return OrderedDict.__getitem__(self, item)
#     265 elif isinstance(item, (int, np.integer)):
#     266     return list(self.values())[item]
#
# KeyError: 'G_Data'

# %%
G_Data_035_045 = G_Filters_035_045["G_Data"]
G_RA_035_045 = G_Filters_035_045["G_RA"]
G_DEC_035_045 = G_Filters_035_045["G_DEC"]
G_Detect_ID_035_045 = G_Filters_035_045["G_Detect_ID"]
G_Z_035_045 = G_Filters_035_045["G_Z"]

R_Data_035_045 = R_Filters_035_045["G_Data"]
R_RA_035_045 = R_Filters_035_045["G_RA"]
R_DEC_035_045 = R_Filters_035_045["G_DEC"]
R_Detect_ID_035_045 = R_Filters_035_045["G_Detect_ID"]
R_Z_035_045 = R_Filters_035_045["G_Z"]

I_Data_035_045 = I_Filters_035_045["G_Data"]
I_RA_035_045 = I_Filters_035_045["G_RA"]
I_DEC_035_045 = I_Filters_035_045["G_DEC"]
I_Detect_ID_035_045 = I_Filters_035_045["G_Detect_ID"]
I_Z_035_045 = I_Filters_035_045["G_Z"]

Z_Data_035_045 = Z_Filters_035_045["G_Data"]
Z_RA_035_045 = Z_Filters_035_045["G_RA"]
Z_DEC_035_045 = Z_Filters_035_045["G_DEC"]
Z_Detect_ID_035_045 = Z_Filters_035_045["G_Detect_ID"]
Z_Z_035_045 = Z_Filters_035_045["G_Z"]

Y_Data_035_045 = Y_Filters_035_045["G_Data"]
Y_RA_035_045 = Y_Filters_035_045["G_RA"]
Y_DEC_035_045 = Y_Filters_035_045["G_DEC"]
Y_Detect_ID_035_045 = Y_Filters_035_045["G_Detect_ID"]
Y_Z_035_045 = Y_Filters_035_045["G_Z"]

# %%
G_Data_045_055 = G_Filters_045_055["G_Data"]
G_RA_045_055 = G_Filters_045_055["G_RA"]
G_DEC_045_055 = G_Filters_045_055["G_DEC"]
G_Detect_ID_045_055 = G_Filters_045_055["G_Detect_ID"]
G_Z_045_055 = G_Filters_045_055["G_Z"]

R_Data_045_055 = R_Filters_045_055["G_Data"]
R_RA_045_055 = R_Filters_045_055["G_RA"]
R_DEC_045_055 = R_Filters_045_055["G_DEC"]
R_Detect_ID_045_055 = R_Filters_045_055["G_Detect_ID"]
R_Z_045_055 = R_Filters_045_055["G_Z"]

I_Data_045_055 = I_Filters_045_055["G_Data"]
I_RA_045_055 = I_Filters_045_055["G_RA"]
I_DEC_045_055 = I_Filters_045_055["G_DEC"]
I_Detect_ID_045_055 = I_Filters_045_055["G_Detect_ID"]
I_Z_045_055 = I_Filters_045_055["G_Z"]

Z_Data_045_055 = Z_Filters_045_055["G_Data"]
Z_RA_045_055 = Z_Filters_045_055["G_RA"]
Z_DEC_045_055 = Z_Filters_045_055["G_DEC"]
Z_Detect_ID_045_055 = Z_Filters_045_055["G_Detect_ID"]
Z_Z_045_055 = Z_Filters_045_055["G_Z"]

Y_Data_045_055 = Y_Filters_045_055["G_Data"]
Y_RA_045_055 = Y_Filters_045_055["G_RA"]
Y_DEC_045_055 = Y_Filters_045_055["G_DEC"]
Y_Detect_ID_045_055 = Y_Filters_045_055["G_Detect_ID"]
Y_Z_045_055 = Y_Filters_045_055["G_Z"]

# %%
G_Data_055_065 = G_Filters_055_065["G_Data"]
G_RA_055_065 = G_Filters_055_065["G_RA"]
G_DEC_055_065 = G_Filters_055_065["G_DEC"]
G_Detect_ID_055_065 = G_Filters_055_065["G_Detect_ID"]
G_Z_055_065 = G_Filters_055_065["G_Z"]

R_Data_055_065 = R_Filters_055_065["G_Data"]
R_RA_055_065 = R_Filters_055_065["G_RA"]
R_DEC_055_065 = R_Filters_055_065["G_DEC"]
R_Detect_ID_055_065 = R_Filters_055_065["G_Detect_ID"]
R_Z_055_065 = R_Filters_055_065["G_Z"]

I_Data_055_065 = I_Filters_055_065["G_Data"]
I_RA_055_065 = I_Filters_055_065["G_RA"]
I_DEC_055_065 = I_Filters_055_065["G_DEC"]
I_Detect_ID_055_065 = I_Filters_055_065["G_Detect_ID"]
I_Z_055_065 = I_Filters_055_065["G_Z"]

Z_Data_055_065 = Z_Filters_055_065["G_Data"]
Z_RA_055_065 = Z_Filters_055_065["G_RA"]
Z_DEC_055_065 = Z_Filters_055_065["G_DEC"]
Z_Detect_ID_055_065 = Z_Filters_055_065["G_Detect_ID"]
Z_Z_055_065 = Z_Filters_055_065["G_Z"]

Y_Data_055_065 = Y_Filters_055_065["G_Data"]
Y_RA_055_065 = Y_Filters_055_065["G_RA"]
Y_DEC_055_065 = Y_Filters_055_065["G_DEC"]
Y_Detect_ID_055_065 = Y_Filters_055_065["G_Detect_ID"]
Y_Z_055_065 = Y_Filters_055_065["G_Z"]

# %%
G_Data_065_075 = G_Filters_065_075["G_Data"]
G_RA_065_075 = G_Filters_065_075["G_RA"]
G_DEC_065_075 = G_Filters_065_075["G_DEC"]
G_Detect_ID_065_075 = G_Filters_065_075["G_Detect_ID"]
G_Z_065_075 = G_Filters_065_075["G_Z"]

R_Data_065_075 = R_Filters_065_075["G_Data"]
R_RA_065_075 = R_Filters_065_075["G_RA"]
R_DEC_065_075 = R_Filters_065_075["G_DEC"]
R_Detect_ID_065_075 = R_Filters_065_075["G_Detect_ID"]
R_Z_065_075 = R_Filters_065_075["G_Z"]

I_Data_065_075 = I_Filters_065_075["G_Data"]
I_RA_065_075 = I_Filters_065_075["G_RA"]
I_DEC_065_075 = I_Filters_065_075["G_DEC"]
I_Detect_ID_065_075 = I_Filters_065_075["G_Detect_ID"]
I_Z_065_075 = I_Filters_065_075["G_Z"]

Z_Data_065_075 = Z_Filters_065_075["G_Data"]
Z_RA_065_075 = Z_Filters_065_075["G_RA"]
Z_DEC_065_075 = Z_Filters_065_075["G_DEC"]
Z_Detect_ID_065_075 = Z_Filters_065_075["G_Detect_ID"]
Z_Z_065_075 = Z_Filters_065_075["G_Z"]

Y_Data_065_075 = Y_Filters_065_075["G_Data"]
Y_RA_065_075 = Y_Filters_065_075["G_RA"]
Y_DEC_065_075 = Y_Filters_065_075["G_DEC"]
Y_Detect_ID_065_075 = Y_Filters_065_075["G_Detect_ID"]
Y_Z_065_075 = Y_Filters_065_075["G_Z"]

# %%
G_Data_075_085 = G_Filters_075_085["G_Data"]
G_RA_075_085 = G_Filters_075_085["G_RA"]
G_DEC_075_085 = G_Filters_075_085["G_DEC"]
G_Detect_ID_075_085 = G_Filters_075_085["G_Detect_ID"]
G_Z_075_085 = G_Filters_075_085["G_Z"]

R_Data_075_085 = R_Filters_075_085["G_Data"]
R_RA_075_085 = R_Filters_075_085["G_RA"]
R_DEC_075_085 = R_Filters_075_085["G_DEC"]
R_Detect_ID_075_085 = R_Filters_075_085["G_Detect_ID"]
R_Z_075_085 = R_Filters_075_085["G_Z"]

I_Data_075_085 = I_Filters_075_085["G_Data"]
I_RA_075_085 = I_Filters_075_085["G_RA"]
I_DEC_075_085 = I_Filters_075_085["G_DEC"]
I_Detect_ID_075_085 = I_Filters_075_085["G_Detect_ID"]
I_Z_075_085 = I_Filters_075_085["G_Z"]

Z_Data_075_085 = Z_Filters_075_085["G_Data"]
Z_RA_075_085 = Z_Filters_075_085["G_RA"]
Z_DEC_075_085 = Z_Filters_075_085["G_DEC"]
Z_Detect_ID_075_085 = Z_Filters_075_085["G_Detect_ID"]
Z_Z_075_085 = Z_Filters_075_085["G_Z"]

Y_Data_075_085 = Y_Filters_075_085["G_Data"]
Y_RA_075_085 = Y_Filters_075_085["G_RA"]
Y_DEC_075_085 = Y_Filters_075_085["G_DEC"]
Y_Detect_ID_075_085 = Y_Filters_075_085["G_Detect_ID"]
Y_Z_075_085 = Y_Filters_075_085["G_Z"]

# %%
G_Data_085_096 = G_Filters_085_096["G_Data"]
G_RA_085_096 = G_Filters_085_096["G_RA"]
G_DEC_085_096 = G_Filters_085_096["G_DEC"]
G_Detect_ID_085_096 = G_Filters_085_096["G_Detect_ID"]
G_Z_085_096 = G_Filters_085_096["G_Z"]

R_Data_085_096 = R_Filters_085_096["G_Data"]
R_RA_085_096 = R_Filters_085_096["G_RA"]
R_DEC_085_096 = R_Filters_085_096["G_DEC"]
R_Detect_ID_085_096 = R_Filters_085_096["G_Detect_ID"]
R_Z_085_096 = R_Filters_085_096["G_Z"]

I_Data_085_096 = I_Filters_085_096["G_Data"]
I_RA_085_096 = I_Filters_085_096["G_RA"]
I_DEC_085_096 = I_Filters_085_096["G_DEC"]
I_Detect_ID_085_096 = I_Filters_085_096["G_Detect_ID"]
I_Z_085_096 = I_Filters_085_096["G_Z"]

Z_Data_085_096 = Z_Filters_085_096["G_Data"]
Z_RA_085_096 = Z_Filters_085_096["G_RA"]
Z_DEC_085_096 = Z_Filters_085_096["G_DEC"]
Z_Detect_ID_085_096 = Z_Filters_085_096["G_Detect_ID"]
Z_Z_085_096 = Z_Filters_085_096["G_Z"]

Y_Data_085_096 = Y_Filters_085_096["G_Data"]
Y_RA_085_096 = Y_Filters_085_096["G_RA"]
Y_DEC_085_096 = Y_Filters_085_096["G_DEC"]
Y_Detect_ID_085_096 = Y_Filters_085_096["G_Detect_ID"]
Y_Z_085_096 = Y_Filters_085_096["G_Z"]

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(1,1, 1)

im = ax.imshow(Y_Data_085_096[0], origin="lower", cmap="YlOrBr")

#plt.scatter(X, Y, color="skyblue", s=200, marker="+")

#sep_ap = cutout['details']['sep_objects'][cutout['details']['sep_obj_idx']]

coord_offset = 0.5 * (ax.get_xlim()[0] + ax.get_xlim()[1])

plt.colorbar(im, ax=ax)

#filename = str(combined_data["Detectid"][200])

#plt.title(str(filename))

# %%
3
